# %%
# Dependencies
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import pymongo
from pymongo import MongoClient
import os

# %%
# Save path to data set in a variable
data_file = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\population-density.csv"

# %%
# Use Pandas to read data
data_file_pd = pd.read_csv(data_file)
data_file_pd.head()
# Out:
#      COUNTRIES Code  Year  Density
# 0  Afghanistan  AFG  1961    14.04
# 1  Afghanistan  AFG  1962    14.32
# 2  Afghanistan  AFG  1963    14.60
# 3  Afghanistan  AFG  1964    14.91
# 4  Afghanistan  AFG  1965    15.22

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
#collection = db.Project2

# %%
# Read the row from data_file to create a dictionary
for _, row in data_file_pd.iterrows():
   dic = {
       'Countries':row["COUNTRIES"],
       'Code': row["Code"],
       'Year': row["Year"],
       'Density': row["Density"]
       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
#collection = db.Energy

# %%
# Define database and collection
db = client.Project2
#collection = db.coordinates

# %%
# Dependencies
# from bs4 import BeautifulSoup
# import requests
# import pymongo
# import pandas as pd

# %%
# URL of page to be scraped
# url = 'https://developers.google.com/public-data/docs/canonical/countries_csv'

# # Retrieve page with the requests module
# response = requests.get(url)
# Create BeautifulSoup object; parse with 'lxml'
# soup = BeautifulSoup(response.text, 'lxml')
# row = [abbr.append(i.text[1])for i in td]

# %%
# Examine the results, then determine element that contains sought info
# results are returned as an iterable list
# table = soup.find('table')
# table_rows = table.find_all('tr')
# # Loop through returned results
# data = []
# for tr in table_rows:
#     td = tr.find_all('td')
#     row = [i.text for i in td]
#     try:
#         data.append({"abbr": (row[0]), 
#                       "Lat": (row[1]), 
#                       "Lng": (row[2]), 
#                       "country": (row[3])})
#     except:
#         pass

# %%
#collection.insert_many(data)

# %%
# Save path to data set in a variable
data_file3 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\TEC.csv"

# %%
# Use Pandas to read data
data_file_pd3 = pd.read_csv(data_file3)
data_file_pd3.head()
# Out:
#    s/n         country  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0    1         Belgium    48    50    51    49    52    53    56    56  ...
# 1    2  Czech Republic    50    45    44    43    41    42    43    43  ...
# 2    3          France   225   237   234   238   231   240   250   244  ...
# 3    4         Germany   355   344   338   335   333   336   348   346  ...
# 4    5           Italy   151   155   154   153   151   159   159   162  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0    56    60    56    54    56    53    53    56    55    53
# 1    43    45    44    43    43    42    42    42    43    43
# 2   255   263   254   254   255   244   248   244   244   243
# 3   310   326   310   311   318   306   308   310   312   301
# 4   170   174   168   161   156   147   153   151   154   155
#
# [5 rows x 31 columns]

# %%
# Save path to data set in a variable
data_file4 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\TEP.csv"
# Use Pandas to read data
data_file_pd4 = pd.read_csv(data_file4)
data_file_pd4.head()
# Out:
#    s/n         country  1990  1991  1992  1993  1994  1995  1996  1997  ...  \
# 0    1         Belgium    13    13    13    12    12    12    12    13  ...
# 1    2  Czech Republic    41    39    37    36    34    33    33    34  ...
# 2    3          France   112   119   120   126   124   128   132   129  ...
# 3    4         Germany   190   169   164   153   145   145   143   145  ...
# 4    5           Italy    26    26    28    29    30    30    31    31  ...
#
#    2009  2010  2011  2012  2013  2014  2015  2016  2017  2018
# 0    15    16    16    14    15    13    11    15    15    12
# 1    32    32    33    33    31    30    29    27    28    28
# 2   129   136   136   135   137   138   139   131   130   135
# 3   126   129   123   123   121   120   120   116   115   115
# 4    32    33    32    35    37    37    36    34    34    36
#
# [5 rows x 31 columns]

# %%
# Save path to data set in a variable
data_file5 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\EBOT.csv"
# Use Pandas to read data
data_file_pd5 = pd.read_csv(data_file5)
data_file_pd5.head()
# Out:
#    s/n         country   1990   1991   1992   1993   1994   1995   1996  \
# 0    1         Belgium   39.7   42.4   43.4   41.8   45.7   47.0   49.6
# 1    2  Czech Republic    7.6    7.0    7.0    6.8    7.7    8.6   10.4
# 2    3          France  120.0  126.8  124.5  116.4  113.4  118.1  123.5
# 3    4         Germany  167.1  181.0  187.9  189.6  193.2  195.4  208.6
# 4    5           Italy  131.6  130.9  133.4  127.3  126.3  134.4  133.9
#
#     1997  ...   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0   49.1  ...   48.6   54.0   48.6   46.5   48.8   47.5   50.8   48.8   48.4
# 1   10.5  ...   11.5   11.6   12.6   11.0   12.0   12.7   13.5   13.7   16.2
# 2  122.5  ...  133.7  132.4  127.5  126.2  125.8  115.6  117.0  118.3  121.4
# 3  209.3  ...  197.8  204.1  199.4  199.3  207.2  196.1  198.5  205.0  210.0
# 4  133.9  ...  141.3  148.5  141.3  132.1  123.2  115.1  121.5  121.3  124.4
#
#     2018
# 0   50.8
# 1   15.8
# 2  116.9
# 3  198.8
# 4  120.7
#
# ...

# %%
# Save path to data set in a variable
data_file6 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\EIG.csv"
# Use Pandas to read data
data_file_pd6 = pd.read_csv(data_file6)
data_file_pd6.head()
# Out:
#    s/n         country   1990   1991   1992   1993   1994   1995   1996  \
# 0    1         Belgium  0.144  0.148  0.147  0.145  0.149  0.148  0.154
# 1    2  Czech Republic  0.220  0.226  0.222  0.215  0.201  0.192  0.190
# 2    3          France  0.121  0.127  0.123  0.126  0.119  0.121  0.125
# 3    4         Germany  0.131  0.121  0.117  0.117  0.113  0.112  0.115
# 4    5           Italy  0.080  0.081  0.080  0.080  0.077  0.079  0.078
#
#     1997  ...   2009   2010   2011   2012   2013   2014   2015   2016   2017  \
# 0  0.148  ...  0.118  0.123  0.113  0.108  0.112  0.105  0.104  0.109  0.105
# 1  0.192  ...  0.134  0.139  0.132  0.132  0.132  0.125  0.119  0.115  0.115
# 2  0.119  ...  0.101  0.102  0.097  0.097  0.096  0.092  0.092  0.089  0.087
# 3  0.113  ...  0.090  0.091  0.083  0.083  0.084  0.080  0.079  0.078  0.077
# 4  0.078  ...  0.075  0.076  0.073  0.072  0.071  0.067  0.069  0.067  0.067
#
#     2018
# 0  0.099
# 1  0.110
# 2  0.086
# 3  0.072
# 4  0.067
#
# ...

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
collection = db.TotalEnergyConsumption

# %%
# Read the row from datafile3 to create a dictionary
for _, row in data_file_pd3.iterrows():
   dic = {
       'country':row["country"],
       '1990': row["1990"],
       '1991': row["1991"],
       '1992': row["1992"],
       '1993': row["1993"],
       '1994': row["1994"],
       '1995': row["1995"],
       '1996': row["1996"],
       '1997': row["1997"],
       '1998': row["1998"],
       '1999': row["1999"],
       '2000': row["2000"],
       '2001': row["2001"],
       '2002': row["2002"],
       '2003': row["2003"],
       '2004': row["2004"],
       '2005': row["2005"],
       '2006': row["2006"],
       '2007': row["2007"],
       '2008': row["2008"],
       '2009': row["2009"],
       '2010': row["2010"],
        '2011': row["2011"],
        '2012': row["2012"],
        '2013': row["2013"],
        '2014': row["2014"],
        '2015': row["2015"],
        '2016': row["2016"],
        '2017': row["2017"],
        '2018': row["2018"]       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
collection = db.TotalEnergyProduction

# %%
# Read the row from datafile4 to create a dictionary
for _, row in data_file_pd4.iterrows():
   dic = {
       'country':row["country"],
       '1990': row["1990"],
       '1991': row["1991"],
       '1992': row["1992"],
       '1993': row["1993"],
       '1994': row["1994"],
       '1995': row["1995"],
       '1996': row["1996"],
       '1997': row["1997"],
       '1998': row["1998"],
       '1999': row["1999"],
       '2000': row["2000"],
       '2001': row["2001"],
       '2002': row["2002"],
       '2003': row["2003"],
       '2004': row["2004"],
       '2005': row["2005"],
       '2006': row["2006"],
       '2007': row["2007"],
       '2008': row["2008"],
       '2009': row["2009"],
       '2010': row["2010"],
        '2011': row["2011"],
        '2012': row["2012"],
        '2013': row["2013"],
        '2014': row["2014"],
        '2015': row["2015"],
        '2016': row["2016"],
        '2017': row["2017"],
        '2018': row["2018"]       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
collection = db.EnergyBalanceOfTrade

# %%
# Read the row from datafile5 to create a dictionary
for _, row in data_file_pd5.iterrows():
   dic = {
       'country':row["country"],
       '1990': row["1990"],
       '1991': row["1991"],
       '1992': row["1992"],
       '1993': row["1993"],
       '1994': row["1994"],
       '1995': row["1995"],
       '1996': row["1996"],
       '1997': row["1997"],
       '1998': row["1998"],
       '1999': row["1999"],
       '2000': row["2000"],
       '2001': row["2001"],
       '2002': row["2002"],
       '2003': row["2003"],
       '2004': row["2004"],
       '2005': row["2005"],
       '2006': row["2006"],
       '2007': row["2007"],
       '2008': row["2008"],
       '2009': row["2009"],
       '2010': row["2010"],
        '2011': row["2011"],
        '2012': row["2012"],
        '2013': row["2013"],
        '2014': row["2014"],
        '2015': row["2015"],
        '2016': row["2016"],
        '2017': row["2017"],
        '2018': row["2018"]       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
collection = db.EnergyIntensityGDP

# %%
# Read the row from datafile6 to create a dictionary
for _, row in data_file_pd6.iterrows():
   dic = {
       'country':row["country"],
       '1990': row["1990"],
       '1991': row["1991"],
       '1992': row["1992"],
       '1993': row["1993"],
       '1994': row["1994"],
       '1995': row["1995"],
       '1996': row["1996"],
       '1997': row["1997"],
       '1998': row["1998"],
       '1999': row["1999"],
       '2000': row["2000"],
       '2001': row["2001"],
       '2002': row["2002"],
       '2003': row["2003"],
       '2004': row["2004"],
       '2005': row["2005"],
       '2006': row["2006"],
       '2007': row["2007"],
       '2008': row["2008"],
       '2009': row["2009"],
       '2010': row["2010"],
        '2011': row["2011"],
        '2012': row["2012"],
        '2013': row["2013"],
        '2014': row["2014"],
        '2015': row["2015"],
        '2016': row["2016"],
        '2017': row["2017"],
        '2018': row["2018"]       
       
   }
   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# Save path to data set in a variable
data_file7 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\TEC2.csv"

# %%
# Use Pandas to read data - TEC2
data_file_pd7 = pd.read_csv(data_file7)
data_file_pd7.head()
# Out:
#   Year  Belgium  Czech Republic  France  Germany  Italy  Netherlands  Poland  \
# 0  yr1       48              50     225      355    151           67     104
# 1  yr2       50              45     237      344    155           69     101
# 2  yr3       51              44     234      338    154           69      99
# 3  yr4       49              43     238      335    153           70     101
# 4  yr5       52              41     231      333    151           71      97
#
#    Portugal  Romania  ...  Australia  New Zealand  Algeria  Egypt  Nigeria  \
# 0        17       62  ...         87           14       22     32       66
# 1        17       51  ...         86           14       23     32       70
# 2        19       47  ...         87           14       24     33       72
# 3        18       46  ...         91           15       24     34       74
# 4        19       43  ...         92           15       23     33       72
#
# ...

# %%
data_file_pd7.set_index('Year')
data_file_pd7.head()
# Out:
#   Year  Belgium  Czech Republic  France  Germany  Italy  Netherlands  Poland  \
# 0  yr1       48              50     225      355    151           67     104
# 1  yr2       50              45     237      344    155           69     101
# 2  yr3       51              44     234      338    154           69      99
# 3  yr4       49              43     238      335    153           70     101
# 4  yr5       52              41     231      333    151           71      97
#
#    Portugal  Romania  ...  Australia  New Zealand  Algeria  Egypt  Nigeria  \
# 0        17       62  ...         87           14       22     32       66
# 1        17       51  ...         86           14       23     32       70
# 2        19       47  ...         87           14       24     33       72
# 3        18       46  ...         91           15       24     34       74
# 4        19       43  ...         92           15       23     33       72
#
# ...

# %%
# data_file_pd7['Year'] = data_file_pd7['Year'].astype(str)
# data_file_pd7.dtypes

# %%
from pandas import *
import seaborn as sns
from IPython.display import HTML
#convert dataframe to HTML
html_table = data_file_pd7.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Year</th>\n      <th>Belgium</th>\n      <th>Czech Republic</th>\n      <th>France</th>\n      <th>Germany</th>\n      <th>Italy</th>\n      <th>Netherlands</th>\n      <th>Poland</th>\n      <th>Portugal</th>\n      <th>Romania</th>\n      <th>Spain</th>\n      <th>Sweden</th>\n      <th>United Kingdom</th>\n      <th>Norway</th>\n      <th>Turkey</th>\n      <th>Kazakhstan</th>\n      <th>Russia</th>\n      <th>Ukraine</th>\n      <th>Uzbekistan</th>\n      <th>Canada</th>\n      <th>United States</th>\n      <th>Argentina</th>\n      <th>Brazil</th>\n      <th>Chile</th>\n      <th>Colombia</th>\n      <th>Mexico</th>\n      <th>Venezuela</th>\n      <th>China</th>\n      <th>India</th>\n      <th>Indonesia</th>\n      <th>Japan</th>\n      <th>Malaysia</th>\n      <th>South Korea</th>\n      <th>Taiwan</th>\n      <th>Thailand</th>\n      <th>Australia</th>\n      <th
# ...

# %%
html_table = html_table.replace('\n',"")
html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Year</th>      <th>Belgium</th>      <th>Czech Republic</th>      <th>France</th>      <th>Germany</th>      <th>Italy</th>      <th>Netherlands</th>      <th>Poland</th>      <th>Portugal</th>      <th>Romania</th>      <th>Spain</th>      <th>Sweden</th>      <th>United Kingdom</th>      <th>Norway</th>      <th>Turkey</th>      <th>Kazakhstan</th>      <th>Russia</th>      <th>Ukraine</th>      <th>Uzbekistan</th>      <th>Canada</th>      <th>United States</th>      <th>Argentina</th>      <th>Brazil</th>      <th>Chile</th>      <th>Colombia</th>      <th>Mexico</th>      <th>Venezuela</th>      <th>China</th>      <th>India</th>      <th>Indonesia</th>      <th>Japan</th>      <th>Malaysia</th>      <th>South Korea</th>      <th>Taiwan</th>      <th>Thailand</th>      <th>Australia</th>      <th>New Zealand</th>      <th>Algeria</th>      <th>Egypt</th>      <th>Nigeria</th
# ...

# %%
# ====== Connection ====== #
# Connection to Mongo
conn = 'mongodb://localhost:27017'
client = pymongo.MongoClient(conn)

# Connection to the database
db = client.Project2

# Connection to the collection
collection = db.TEC2

# %%
# Read the row from datafile7 to create a dictionary
for _, row in data_file_pd7.iterrows():
   dic = {
       'Year':row["Year"],
       'Belgium': row["Belgium"], 
       'Czech Republic': row["Czech Republic"],
       'France': row["France"],
       'Germany': row["Germany"],
       'Italy': row["Italy"],
       'Netherlands': row["Netherlands"], 
       'Poland': row["Poland"],
       'Portugal': row["Portugal"],   
       'Romania': row["Romania"],
       'Spain': row["Spain"],
       'Sweden': row["Sweden"],
       'United Kingdom': row["United Kingdom"],
       'Norway': row["Norway"],
       'Turkey': row["Turkey"],
       'Kazakhstan': row["Kazakhstan"],
       'Russia': row["Russia"],
       'Ukraine': row["Ukraine"],
       'Uzbekistan': row["Uzbekistan"],
       'Canada': row["Canada"],
       'United States': row["United States"],
       'Argentina': row["Argentina"],
        'Brazil': row["Brazil"],
        'Chile': row["Chile"],
        'Colombia': row["Colombia"],
        'Mexico': row["Mexico"],
        'Venezuela': row["Venezuela"],
        'China': row["China"],
        'India': row["India"],
        'Indonesia': row["Indonesia"],      
        'Japan': row["Japan"],
       'Malaysia': row["Malaysia"],
       'South Korea': row["South Korea"],
       'Taiwan': row["Taiwan"],
       'Thailand': row["Thailand"],
        'Australia': row["Australia"],
        'New Zealand': row["New Zealand"],
        'Algeria': row["Algeria"],
        'Egypt': row["Egypt"],
        'Nigeria': row["Nigeria"],
        'South Africa': row["South Africa"],
        'Iran': row["Iran"],
        'Kuwait': row["Kuwait"],
        'Saudi Arabia': row["Saudi Arabia"],
        'United Arab Emirates': row["United Arab Emirates"]  
       
   }


   #insert dictionary into mongo
   #collection.insert_one(dic)

# %%
# Save path to data set in a variable
data_file8 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\TEP2.csv"

# %%
# Use Pandas to read data
data_file_pd8 = pd.read_csv(data_file8)
data_file_pd8.head()
# Out:
#    Year  Belgium  Czech Republic  France  Germany  Italy  Netherlands  Poland  \
# 0  1990       13              41     112      190     26           61     104
# 1  1991       13              39     119      169     26           68     100
# 2  1992       13              37     120      164     28           68      98
# 3  1993       12              36     126      153     29           69      97
# 4  1994       12              34     124      145     30           67      98
#
#    Portugal  Romania  ...  Australia  New Zealand  Algeria  Egypt  Nigeria  \
# 0         3       41  ...        157           12      100     55      146
# 1         3       36  ...        167           13      103     56      152
# 2         3       34  ...        171           13      104     57      158
# 3         3       33  ...        174           14      105     60      160
# 4         3       32  ...        173           13      101     59      162
#
# ...

# %%
# data_file_pd8['Year'] = data_file_pd8['Year'].astype(str)
# data_file_pd8.dtypes

# %%
data_file_pd8 = data_file_pd8.drop([x for x in range(0,28)])
data_file_pd8
# Out:
#     Year  Belgium  Czech Republic  France  Germany  Italy  Netherlands  \
# 28  2018       12              28     135      115     36           31
#
#     Poland  Portugal  Romania  ...  Australia  New Zealand  Algeria  Egypt  \
# 28      64         6       25  ...        426           15      151     80
#
#     Nigeria  South Africa  Iran  Kuwait  Saudi Arabia  United Arab Emirates
# 28      256           164   418     168           676                   234
#
# [1 rows x 45 columns]

# %%
data_file_pd8=data_file_pd8.transpose()
data_file_pd8.head()
# Out:
#                   28
# Year            2018
# Belgium           12
# Czech Republic    28
# France           135
# Germany          115

# %%
#convert dataframe to HTML- TEP2
html_table = data_file_pd8.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>28</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>Year</th>\n      <td>2018</td>\n    </tr>\n    <tr>\n      <th>Belgium</th>\n      <td>12</td>\n    </tr>\n    <tr>\n      <th>Czech Republic</th>\n      <td>28</td>\n    </tr>\n    <tr>\n      <th>France</th>\n      <td>135</td>\n    </tr>\n    <tr>\n      <th>Germany</th>\n      <td>115</td>\n    </tr>\n    <tr>\n      <th>Italy</th>\n      <td>36</td>\n    </tr>\n    <tr>\n      <th>Netherlands</th>\n      <td>31</td>\n    </tr>\n    <tr>\n      <th>Poland</th>\n      <td>64</td>\n    </tr>\n    <tr>\n      <th>Portugal</th>\n      <td>6</td>\n    </tr>\n    <tr>\n      <th>Romania</th>\n      <td>25</td>\n    </tr>\n    <tr>\n      <th>Spain</th>\n      <td>34</td>\n    </tr>\n    <tr>\n      <th>Sweden</th>\n      <td>37</td>\n    </tr>\n    <tr>\n      <th>United Kingdom</th>\n      <td>124</td>\n    </t
# ...

# %%
html_table = html_table.replace('\n',"")
html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>28</th>    </tr>  </thead>  <tbody>    <tr>      <th>Year</th>      <td>2018</td>    </tr>    <tr>      <th>Belgium</th>      <td>12</td>    </tr>    <tr>      <th>Czech Republic</th>      <td>28</td>    </tr>    <tr>      <th>France</th>      <td>135</td>    </tr>    <tr>      <th>Germany</th>      <td>115</td>    </tr>    <tr>      <th>Italy</th>      <td>36</td>    </tr>    <tr>      <th>Netherlands</th>      <td>31</td>    </tr>    <tr>      <th>Poland</th>      <td>64</td>    </tr>    <tr>      <th>Portugal</th>      <td>6</td>    </tr>    <tr>      <th>Romania</th>      <td>25</td>    </tr>    <tr>      <th>Spain</th>      <td>34</td>    </tr>    <tr>      <th>Sweden</th>      <td>37</td>    </tr>    <tr>      <th>United Kingdom</th>      <td>124</td>    </tr>    <tr>      <th>Norway</th>      <td>207</td>    </tr>    <tr>      <th>Turkey</th>      <td>43</td>    </tr>    <
# ...

# %%
# Save path to data set in a variable
data_file9 = "C:\\Users\\taiwo\\OneDrive\\Desktop\\PREWORK_TO\\Module 16\\Project2\\Data Files\\EBOT2.csv"

# %%
# Use Pandas to read data
data_file_pd9 = pd.read_csv(data_file9)
data_file_pd9.head()
# Out:
#    Year  Belgium  Czech Republic  France  Germany  Italy  Netherlands  Poland  \
# 0  1990     39.7             7.6   120.0    167.1  131.6         19.0     1.3
# 1  1991     42.4             7.0   126.8    181.0  130.9         15.5     1.4
# 2  1992     43.4             7.0   124.5    187.9  133.4         15.2     1.9
# 3  1993     41.8             6.8   116.4    189.6  127.3         14.4     3.0
# 4  1994     45.7             7.7   113.4    193.2  126.3         18.7     0.7
#
#    Portugal  Romania  ...  Australia  New Zealand  Algeria  Egypt  Nigeria  \
# 0      15.3     22.0  ...      -63.4          2.1    -77.3  -20.8    -79.4
# 1      15.2     14.5  ...      -78.7          1.9    -78.5  -20.8    -82.4
# 2      16.7     13.7  ...      -81.8          2.0    -79.6  -22.9    -85.2
# 3      16.0     12.3  ...      -83.3          2.0    -80.0  -23.5    -86.5
# 4      16.3     11.0  ...      -82.3          2.8    -76.8  -23.3    -89.2
#
# ...

# %%
data_file_pd9 = data_file_pd9.drop([x for x in range(0,28)])
data_file_pd9
# Out:
#     Year  Belgium  Czech Republic  France  Germany  Italy  Netherlands  \
# 28  2018     50.8            15.8   116.9    198.8  120.7         52.9
#
#     Poland  Portugal  Romania  ...  Australia  New Zealand  Algeria  Egypt  \
# 28    46.6      17.6      7.9  ...     -289.4          6.8    -91.5   10.5
#
#     Nigeria  South Africa   Iran  Kuwait  Saudi Arabia  United Arab Emirates
# 28   -101.3         -18.7 -150.5  -133.1        -459.3                -130.5
#
# [1 rows x 45 columns]

# %%
# data_file_pd9.transpose().head()

# %%
#convert dataframe to HTML - EBOT2
html_table = data_file_pd9.to_html()
html_table
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>Year</th>\n      <th>Belgium</th>\n      <th>Czech Republic</th>\n      <th>France</th>\n      <th>Germany</th>\n      <th>Italy</th>\n      <th>Netherlands</th>\n      <th>Poland</th>\n      <th>Portugal</th>\n      <th>Romania</th>\n      <th>Spain</th>\n      <th>Sweden</th>\n      <th>United Kingdom</th>\n      <th>Norway</th>\n      <th>Turkey</th>\n      <th>Kazakhstan</th>\n      <th>Russia</th>\n      <th>Ukraine</th>\n      <th>Uzbekistan</th>\n      <th>Canada</th>\n      <th>United States</th>\n      <th>Argentina</th>\n      <th>Brazil</th>\n      <th>Chile</th>\n      <th>Colombia</th>\n      <th>Mexico</th>\n      <th>Venezuela</th>\n      <th>China</th>\n      <th>India</th>\n      <th>Indonesia</th>\n      <th>Japan</th>\n      <th>Malaysia</th>\n      <th>South Korea</th>\n      <th>Taiwan</th>\n      <th>Thailand</th>\n      <th>Australia</th>\n      <th
# ...

# %%
html_table = html_table.replace('\n',"")
html_table
# Out:
# '<table border="1" class="dataframe">  <thead>    <tr style="text-align: right;">      <th></th>      <th>Year</th>      <th>Belgium</th>      <th>Czech Republic</th>      <th>France</th>      <th>Germany</th>      <th>Italy</th>      <th>Netherlands</th>      <th>Poland</th>      <th>Portugal</th>      <th>Romania</th>      <th>Spain</th>      <th>Sweden</th>      <th>United Kingdom</th>      <th>Norway</th>      <th>Turkey</th>      <th>Kazakhstan</th>      <th>Russia</th>      <th>Ukraine</th>      <th>Uzbekistan</th>      <th>Canada</th>      <th>United States</th>      <th>Argentina</th>      <th>Brazil</th>      <th>Chile</th>      <th>Colombia</th>      <th>Mexico</th>      <th>Venezuela</th>      <th>China</th>      <th>India</th>      <th>Indonesia</th>      <th>Japan</th>      <th>Malaysia</th>      <th>South Korea</th>      <th>Taiwan</th>      <th>Thailand</th>      <th>Australia</th>      <th>New Zealand</th>      <th>Algeria</th>      <th>Egypt</th>      <th>Nigeria</th
# ...
